# %%
import pandas as pd
df1=pd.read_csv("/content/drive/My Drive/bottle.csv")
df1
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Cst_Cnt  Btl_Cnt       Sta_ID  ... pH2  pH1  DIC Quality Comment
# 0             1        1  054.0 056.0  ... NaN  NaN                  NaN
# 1             1        2  054.0 056.0  ... NaN  NaN                  NaN
# 2             1        3  054.0 056.0  ... NaN  NaN                  NaN
# 3             1        4  054.0 056.0  ... NaN  NaN                  NaN
# 4             1        5  054.0 056.0  ... NaN  NaN                  NaN
# ...         ...      ...          ...  ...  ..  ...                  ...
# 864858    34404   864859  093.4 026.4  ... NaN  NaN                  NaN
# 864859    34404   864860  093.4 026.4  ... NaN  NaN                  NaN
# ...

# %%
import pandas as pd
df2=pd.read_csv("/content/drive/My Drive/cast.csv")
df2
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Cst_Cnt          Cruise_ID  Cruise  ...  Cloud_Typ  Cloud_Amt Visibility
# 0            1  1949-03-01-C-31CR  194903  ...        NaN        NaN        NaN
# 1            2  1949-03-01-C-31CR  194903  ...        NaN        NaN        NaN
# 2            3  1949-03-01-C-31CR  194903  ...        NaN        NaN        NaN
# 3            4  1949-03-01-C-31CR  194903  ...        NaN        NaN        NaN
# 4            5  1949-03-01-C-31CR  194903  ...        NaN        NaN        NaN
# ...        ...                ...     ...  ...        ...        ...        ...
# 34399    34400  2016-11-06-C-33SR  201611  ...        NaN        NaN        NaN
# ...

# %%
import pandas as pd
df3=pd.read_csv("/content/drive/My Drive/weatherHistory.csv")
df3
# Out:
#                       Formatted Date  ...                           Daily Summary
# 0      2006-04-01 00:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 1      2006-04-01 01:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 2      2006-04-01 02:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 3      2006-04-01 03:00:00.000 +0200  ...       Partly cloudy throughout the day.
# 4      2006-04-01 04:00:00.000 +0200  ...       Partly cloudy throughout the day.
# ...                              ...  ...                                     ...
# 96448  2016-09-09 19:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96449  2016-09-09 20:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96450  2016-09-09 21:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# 96451  2016-09-09 22:00:00.000 +0200  ...  Partly cloudy starting in the morning.
# ...

# %%
import pandas as pd
df4=pd.read_csv("/content/drive/My Drive/Weather Station Locations.csv")
df4
# Out:
#       WBAN            NAME STATE/COUNTRY ID  ...  ELEV   Latitude  Longitude
# 0    33013          AIN EL               AL  ...   611  36.383333   6.650000
# 1    33031        LA SENIA               AL  ...    88  35.616667   0.583333
# 2    33023  MAISON BLANCHE               AL  ...    23  36.716667   3.216667
# 3    33044        TELERGMA               AL  ...   754  36.116667   6.416667
# 4    12001         TINDOUF               AL  ...   443  27.683333  -8.083333
# ..     ...             ...              ...  ...   ...        ...        ...
# 156  33109       EL AQUINA               TS  ...     4  36.850000  10.016667
# 157  33121         EL DJEM               TS  ...  9999  35.333333  10.066667
# 158  33003      SISI AHMED               TS  ...     4  37.200000   9.083333
# 159  33307           ADANA               TU  ...    20  36.983333  35.016667
# 160  15027      WARRINGTON               UK  ...    27  53.383333  -2.050000
#
# [161 rows x 8 columns]

# %%
import pandas as pd
df5=pd.read_csv("/content/drive/My Drive/Summary of Weather.csv")
df5
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           STA        Date Precip  WindGustSpd  ...  RHX  RHN  RVG WTE
# 0       10001    1942-7-1  1.016          NaN  ...  NaN  NaN  NaN NaN
# 1       10001    1942-7-2      0          NaN  ...  NaN  NaN  NaN NaN
# 2       10001    1942-7-3   2.54          NaN  ...  NaN  NaN  NaN NaN
# 3       10001    1942-7-4   2.54          NaN  ...  NaN  NaN  NaN NaN
# 4       10001    1942-7-5      0          NaN  ...  NaN  NaN  NaN NaN
# ...       ...         ...    ...          ...  ...  ...  ...  ...  ..
# 119035  82506  1945-12-27      0          NaN  ...  NaN  NaN  NaN NaN
# 119036  82506  1945-12-28  9.906          NaN  ...  NaN  NaN  NaN NaN
# 119037  82506  1945-12-29      0          NaN  ...  NaN  NaN  NaN NaN
# ...

# %% [markdown]
# Size of data

# %%
df1=pd.read_csv("/content/drive/My Drive/bottle.csv")
df1.size
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 63999862

# %%
df2=pd.read_csv("/content/drive/My Drive/cast.csv")
df2.size
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 2098644

# %%
df3=pd.read_csv("/content/drive/My Drive/weatherHistory.csv")
df3.size
# Out:
# 1157436

# %%
df4=pd.read_csv("/content/drive/My Drive/Weather Station Locations.csv")
df4.size
# Out:
# 1288

# %%
df5=pd.read_csv("/content/drive/My Drive/Summary of Weather.csv")
df5.size
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# 3690240

# %% [markdown]
# shape of data

# %%
df1=pd.read_csv("/content/drive/My Drive/bottle.csv")
df1.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (864863, 74)

# %%
df2=pd.read_csv("/content/drive/My Drive/cast.csv")
df2.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (34404, 61)

# %%
df3=pd.read_csv("/content/drive/My Drive/weatherHistory.csv")
df3.shape
# Out:
# (96453, 12)

# %%
df4=pd.read_csv("/content/drive/My Drive/Weather Station Locations.csv")
df4.shape
# Out:
# (161, 8)

# %%
df5=pd.read_csv("/content/drive/My Drive/Summary of Weather.csv")
df5.shape
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (119040, 31)

# %% [markdown]
# null values

# %%
df1=pd.read_csv("/content/drive/My Drive/bottle.csv")
df1.isnull()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         Cst_Cnt  Btl_Cnt  Sta_ID  ...   pH2   pH1  DIC Quality Comment
# 0         False    False   False  ...  True  True                 True
# 1         False    False   False  ...  True  True                 True
# 2         False    False   False  ...  True  True                 True
# 3         False    False   False  ...  True  True                 True
# 4         False    False   False  ...  True  True                 True
# ...         ...      ...     ...  ...   ...   ...                  ...
# 864858    False    False   False  ...  True  True                 True
# 864859    False    False   False  ...  True  True                 True
# 864860    False    False   False  ...  True  True                 True
# ...

# %%
df2=pd.read_csv("/content/drive/My Drive/cast.csv")
df2.isnull()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Cst_Cnt  Cruise_ID  Cruise  ...  Cloud_Typ  Cloud_Amt  Visibility
# 0        False      False   False  ...       True       True        True
# 1        False      False   False  ...       True       True        True
# 2        False      False   False  ...       True       True        True
# 3        False      False   False  ...       True       True        True
# 4        False      False   False  ...       True       True        True
# ...        ...        ...     ...  ...        ...        ...         ...
# 34399    False      False   False  ...       True       True        True
# 34400    False      False   False  ...       True       True        True
# ...

# %%
df3=pd.read_csv("/content/drive/My Drive/weatherHistory.csv")
df3.isnull()
# Out:
#        Formatted Date  Summary  ...  Pressure (millibars)  Daily Summary
# 0               False    False  ...                 False          False
# 1               False    False  ...                 False          False
# 2               False    False  ...                 False          False
# 3               False    False  ...                 False          False
# 4               False    False  ...                 False          False
# ...               ...      ...  ...                   ...            ...
# 96448           False    False  ...                 False          False
# 96449           False    False  ...                 False          False
# 96450           False    False  ...                 False          False
# 96451           False    False  ...                 False          False
# 96452           False    False  ...                 False          False
#
# [96453 rows x 12 columns]

# %%
df4=pd.read_csv("/content/drive/My Drive/Weather Station Locations.csv")
df4.isnull()
# Out:
#       WBAN   NAME  STATE/COUNTRY ID    LAT    LON   ELEV  Latitude  Longitude
# 0    False  False             False  False  False  False     False      False
# 1    False  False             False  False  False  False     False      False
# 2    False  False             False  False  False  False     False      False
# 3    False  False             False  False  False  False     False      False
# 4    False  False             False  False  False  False     False      False
# ..     ...    ...               ...    ...    ...    ...       ...        ...
# 156  False  False             False  False  False  False     False      False
# 157  False  False             False  False  False  False     False      False
# 158  False  False             False  False  False  False     False      False
# 159  False  False             False  False  False  False     False      False
# 160  False  False             False  False  False  False     False      False
#
# [161 rows x 8 columns]

# %%
df5=pd.read_csv("/content/drive/My Drive/Summary of Weather.csv")
df5.isnull()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           STA   Date  Precip  WindGustSpd  ...   RHX   RHN   RVG   WTE
# 0       False  False   False         True  ...  True  True  True  True
# 1       False  False   False         True  ...  True  True  True  True
# 2       False  False   False         True  ...  True  True  True  True
# 3       False  False   False         True  ...  True  True  True  True
# 4       False  False   False         True  ...  True  True  True  True
# ...       ...    ...     ...          ...  ...   ...   ...   ...   ...
# 119035  False  False   False         True  ...  True  True  True  True
# 119036  False  False   False         True  ...  True  True  True  True
# 119037  False  False   False         True  ...  True  True  True  True
# ...

# %% [markdown]
# remove null values with showing shape and size of remaining data

# %%
df1=pd.read_csv("/content/drive/My Drive/bottle.csv")
df1.dropna(axis=1).shape
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (864863, 8)

# %%
df2=pd.read_csv("/content/drive/My Drive/cast.csv")
df2.dropna(axis=1).shape
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (34404, 32)

# %%
df3=pd.read_csv("/content/drive/My Drive/weatherHistory.csv")
df3.dropna(axis=1).shape
# Out:
# (96453, 11)

# %%
df4=pd.read_csv("/content/drive/My Drive/Weather Station Locations.csv")
df4.dropna(axis=1).shape
# Out:
# (161, 8)

# %%
df5=pd.read_csv("/content/drive/My Drive/Summary of Weather.csv")
df5.dropna(axis=1).shape
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (119040, 9)

# %%
df1=pd.read_csv("/content/drive/My Drive/bottle.csv")
df1.dropna(axis=1).corr(method ='pearson')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (47,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#           Cst_Cnt   Btl_Cnt    Depthm    RecInd   R_Depth    R_PRES
# Cst_Cnt  1.000000  0.999345 -0.162222 -0.100142 -0.162220 -0.161961
# Btl_Cnt  0.999345  1.000000 -0.161617 -0.100828 -0.161614 -0.161348
# Depthm  -0.162222 -0.161617  1.000000  0.082316  1.000000  0.999994
# RecInd  -0.100142 -0.100828  0.082316  1.000000  0.082317  0.082183
# R_Depth -0.162220 -0.161614  1.000000  0.082317  1.000000  0.999994
# R_PRES  -0.161961 -0.161348  0.999994  0.082183  0.999994  1.000000

# %%
df2=pd.read_csv("/content/drive/My Drive/cast.csv")
df2.dropna(axis=1).corr(method ='pearson')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (40,41,44,45,46,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#               Cst_Cnt    Cruise  Cruz_Sta  ...   Rpt_Sta  St_Station    Ac_Sta
# Cst_Cnt      1.000000  0.979474  0.979474  ...  0.001131    0.001147  0.009648
# Cruise       0.979474  1.000000  1.000000  ...  0.012956    0.012969  0.022247
# Cruz_Sta     0.979474  1.000000  1.000000  ...  0.012953    0.012966  0.022243
# DbSta_ID    -0.196692 -0.221306 -0.221296  ... -0.284414   -0.284398 -0.315349
# Quarter      0.013479  0.005393  0.005393  ...  0.030057    0.030034  0.032554
# Year         0.979457  0.999999  0.999999  ...  0.012933    0.012946  0.022220
# Month       -0.022709 -0.033847 -0.033847  ...  0.013393    0.013369  0.014888
# Julian_Date  0.981575  0.993224  0.993224  ...  0.013481    0.013494  0.022879
# ...

# %%
df3=pd.read_csv("/content/drive/My Drive/weatherHistory.csv")
df3.dropna(axis=1).corr(method ='pearson')
# Out:
#                           Temperature (C)  ...  Pressure (millibars)
# Temperature (C)                  1.000000  ...             -0.005447
# Apparent Temperature (C)         0.992629  ...             -0.000219
# Humidity                        -0.632255  ...              0.005454
# Wind Speed (km/h)                0.008957  ...             -0.049263
# Wind Bearing (degrees)           0.029988  ...             -0.011651
# Visibility (km)                  0.392847  ...              0.059818
# Loud Cover                            NaN  ...                   NaN
# Pressure (millibars)            -0.005447  ...              1.000000
#
# [8 rows x 8 columns]

# %%
df4=pd.read_csv("/content/drive/My Drive/Weather Station Locations.csv")
df4.dropna(axis=1).corr(method ='pearson')
# Out:
#                WBAN      ELEV  Latitude  Longitude
# WBAN       1.000000 -0.175145 -0.549497   0.620293
# ELEV      -0.175145  1.000000 -0.037603  -0.050088
# Latitude  -0.549497 -0.037603  1.000000  -0.115382
# Longitude  0.620293 -0.050088 -0.115382   1.000000

# %%
df5=pd.read_csv("/content/drive/My Drive/Summary of Weather.csv")
df5.dropna(axis=1).corr(method ='pearson')
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7,8,18,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                STA   MaxTemp   MinTemp  MeanTemp        YR        MO        DA
# STA       1.000000  0.092371  0.059319  0.078112  0.121408 -0.008592  0.000903
# MaxTemp   0.092371  1.000000  0.878384  0.969048  0.039585  0.031346 -0.005130
# MinTemp   0.059319  0.878384  1.000000  0.965425 -0.020733  0.069078 -0.002576
# MeanTemp  0.078112  0.969048  0.965425  1.000000  0.010681  0.050769 -0.004153
# YR        0.121408  0.039585 -0.020733  0.010681  1.000000 -0.144360 -0.011196
# MO       -0.008592  0.031346  0.069078  0.050769 -0.144360  1.000000  0.006563
# DA        0.000903 -0.005130 -0.002576 -0.004153 -0.011196  0.006563  1.000000

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

df1 = pd.read_csv(/content/drive/My Drive/bottle.csv")
array = df1.values
X = array[:,0:8]
Y = array[:,8]

seed = 7

models = []
models.append(('LR', LogisticRegression()))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC()))

results = []
names = []
scoring = 'accuracy'
for name, model in models:
	kfold = model_selection.KFold(n_splits=10, random_state=seed)
	cv_results = model_selection.cross_val_score(model, X, Y, cv=kfold, scoring=scoring)
	results.append(cv_results)
	names.append(name)
	msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
	print(msg)

fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
