# %% [markdown]
# pandas

# %%
#1-d array is series and 2-d array is called as frame
import pandas as pd
import numpy as np
from numpy.random import randn
np.random.seed(101)
df=pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())
print(df)
#call by column
print(df['X'])
#callby two column
print(df[['W','X']])
#type
type(df['W'])
type(df[['W','X']])
#creating new function
df['new']=df['W']+df['Y']
print(df)
#view as drop in pythom
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64
#           W         X
# A  2.706850  0.628133
# B  0.651118 -0.319318
# C -2.018168  0.740122
# D  0.188695 -0.758872
# E  0.190794  1.978757
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# ...

# %%
#inplace for delete
df.drop('X',axis=1,inplace=True)
print(df)
# Out:
#           W         Y         Z       new
# A  2.706850  0.907969  0.503826  3.614819
# B  0.651118 -0.848077  0.605965 -0.196959
# C -2.018168  0.528813 -0.589001 -1.489355
# D  0.188695 -0.933237  0.955057 -0.744542
# E  0.190794  2.605967  0.683509  2.796762

# %% [markdown]
# selecting rows

# %%
df.loc['A']
df.iloc[2]
# Out:
# W     -2.018168
# Y      0.528813
# Z     -0.589001
# new   -1.489355
# Name: C, dtype: float64

# %% [markdown]
# sinngle row nd single column

# %%
df.loc['A','W']
# Out:
# 2.706849839399938

# %% [markdown]
# two column and two rows

# %%
df.loc[[('A','B'),('W','X')]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-95735a160eb8> in <module>()
# ----> 1 df.loc[[('A','B'),('W','X')]]
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1952                     raise ValueError("Cannot index with multidimensional key")
#    1953
# -> 1954                 return self._getitem_iterable(key, axis=axis)
#    1955
#    1956             # nested tuple slicing
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py in _getitem_iterable(self, key, axis)
# ...

# %% [markdown]
# greater value

# %%
df>0
# Out:
#        W      Y      Z    new
# A   True   True   True   True
# B   True  False   True  False
# C  False   True  False  False
# D   True  False   True  False
# E   True   True   True   True

# %% [markdown]
# display value of greater than

# %%
df[df>0]
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118       NaN  0.605965
# C       NaN  0.528813       NaN
# D  0.188695       NaN  0.955057
# E  0.190794  2.605967  0.683509

# %% [markdown]
# conditional statement

# %%
df[df['W']<0]
# Out:
#           W         Y         Z       new
# C -2.018168  0.528813 -0.589001 -1.489355

# %% [markdown]
# displat the column y and z for which w>0

# %%
df[df['W']>0,df['Y','Z']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Y', 'Z')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-0e6533b61699> in <module>()
# ----> 1 df[df['W']>0,df['Y','Z']]
#
# ...

# %% [markdown]
# display the data frame for which w>0 and z>1

# %%
df[(df['W']>0)&(df['Z']>1)]
# Out:
# Empty DataFrame
# Columns: [W, Y, Z]
# Index: []

# %% [markdown]
# display the data fro ant values greater than 1

# %%
df>0
# Out:
#        W      Y      Z
# A   True   True   True
# B   True  False   True
# C  False   True  False
# D   True  False   True
# E   True   True   True

# %% [markdown]
# display the value for which x is greater than 0

# %%
df[df['X']>0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'X'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-17-863b0a6fa1ab> in <module>()
# ----> 1 df[df['X']>0]
#
# ...

# %% [markdown]
# reset index to default

# %%
df.reset_index()
# Out:
#   index         W         Y         Z
# 0     A  2.706850  0.907969  0.503826
# 1     B  0.651118 -0.848077  0.605965
# 2     C -2.018168  0.528813 -0.589001
# 3     D  0.188695 -0.933237  0.955057
# 4     E  0.190794  2.605967  0.683509

# %% [markdown]
# creating new state

# %%
newInd='MP UP AP KARNATAKA DELHI'.split()
df['states']=newInd
print(df)
df.set_index('states')
print(df)
# Out:
#           W         Y         Z     states
# A  2.706850  0.907969  0.503826         MP
# B  0.651118 -0.848077  0.605965         UP
# C -2.018168  0.528813 -0.589001         AP
# D  0.188695 -0.933237  0.955057  KARNATAKA
# E  0.190794  2.605967  0.683509      DELHI
#           W         Y         Z     states
# A  2.706850  0.907969  0.503826         MP
# B  0.651118 -0.848077  0.605965         UP
# C -2.018168  0.528813 -0.589001         AP
# D  0.188695 -0.933237  0.955057  KARNATAKA
# E  0.190794  2.605967  0.683509      DELHI

# %% [markdown]
# index levels

# %%
outside=['g1','g1','g1','g2','g2','g2']
inside=[1,2,3,1,2,3]
hier_index= list(zip(outside,inside))
hier_index=pd.MultiIndex.from_tuples(hier_index)
print(hier_index)
# Out:
# MultiIndex([('g1', 1),
#             ('g1', 2),
#             ('g1', 3),
#             ('g2', 1),
#             ('g2', 2),
#             ('g2', 3)],
#            )

# %% [markdown]
# matrix hier index

# %%
pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
# Out:
#              A         B
# g1 1 -0.497104 -0.754070
#    2 -0.943406  0.484752
#    3 -0.116773  1.901755
# g2 1  0.238127  1.996652
#    2 -0.993263  0.196800
#    3 -1.136645  0.000366

# %% [markdown]
# loaction of particular

# %%
df.loc('g1')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6862b185ea2> in <module>()
# ----> 1 df.loc('g1')
#
# NameError: name 'df' is not defined

# %% [markdown]
# frozen list

# %%
df.index.name=['group','num']
df.index.names
# Out:
# FrozenList([['group', 'num']])

# %% [markdown]
# cvdv

# %%
df.xs('g1')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'g1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-59-f2b6735bb4bd> in <module>()
# ----> 1 df.xs('g1')
#
# ...

# %% [markdown]
# create the list of branch having elemnet cs, ec, mech,it,civil
# create another list year 1,2,3,4 repetedly as per branch
# create multiindex list using data frame of random number5,4 with using 2 sections
